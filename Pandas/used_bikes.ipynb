# %% [markdown]
# * Pandas is a powerful and easy-to-use data analysis and manipulation library for Python. It is especially useful when working with structured data (like tables, Excel files, or SQL results).
#
#
# | Feature                 | Description                                                     |
# | ----------------------- | --------------------------------------------------------------- |
# | *DataFrame & Series*  | Core data structures to store tabular and one-dimensional data. |
# | *Read/Write Files*    | Load data from CSV, Excel, SQL, JSON, etc.                      |
# | *Data Cleaning*       | Handle missing values, remove duplicates, filter rows.          |
# | *Data Manipulation*   | Merge, join, group, sort, pivot, and reshape data.              |
# | *Statistics*          | Built-in functions like mean, median, standard deviation.       |
# | *Time Series Support* | Great tools for handling date and time data.                    |

# %%
import pandas as pd

# %%
df=pd.read_csv('Used_Bikes.csv')

# %%
df=pd.read_csv(r"C:\Users\nanus\OneDrive\Desktop\DS 1st JUly\Data-Science\Pandas\Used_Bikes.csv")   # used to read csv file

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols: 'UsecolsArgType' = None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters: 'Mapping[Hashable, Callable] | None' = None, true_values: 'list | None' = None, false_values: 'list | None' = None, skipinitialspace: 'bool' = False, skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool | lib.NoDefault' = <no_defau
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info()   #used to get information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.duplicated()   #used to check for duplicate values in the dataframe
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()   #used to count the number of duplicate values in the dataframe
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)   #used to drop duplicate values in the dataframe

# %%
df.duplicated().sum()   #used to count the number of duplicate values in the dataframe
# Out:
# np.int64(0)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.describe()   #used to get the statistical summary of the dataframe
# Out:
#               price     kms_driven          age        power
# count  7.324000e+03    7324.000000  7324.000000  7324.000000
# mean   8.488390e+04   23910.496587     6.656472   228.133397
# std    1.209662e+05   27317.594631     3.605299   158.324219
# min    4.400000e+03       1.000000     1.000000   100.000000
# 25%    3.000000e+04   10155.750000     4.000000   125.000000
# 50%    5.500000e+04   19000.000000     6.000000   160.000000
# 75%    1.000000e+05   30112.000000     8.000000   350.000000
# max    1.900000e+06  750000.000000    63.000000  1800.000000

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.head(10)   #used to get the first 5 rows of the dataframe if want to see more rows, you can change the number in the brackets
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10)   #used to get the last 5 rows of the dataframe if want to see more rows, you can change the number in the brackets
# Out:
#                            bike_name     price       city  kms_driven  \
# 9348                  KTM Duke 390cc  195000.0     Mumbai      4568.0
# 9349             Bajaj Pulsar  180cc   55000.0       Pune     10000.0
# 9350              Bajaj Pulsar NS200   46000.0  Bangalore     27687.0
# 9360              Bajaj Pulsar NS200   48000.0  Allahabad     41939.0
# 9361             Bajaj Avenger 220cc   50000.0  Bangalore     29134.0
# 9362       Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369             Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370  Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371           Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372        Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 9348  First Owner  4.0  390.0              KTM
# 9349  First Owner  6.0  180.0            Bajaj
# 9350  Third Owner  9.0  200.0            Bajaj
# ...

# %%
df.columns   #used to get the columns of the dataframe
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.price   #used to get the price column of the dataframe
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
df.brand   #used to get the brand column of the dataframe
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['brand']   #used to get the brand column of the dataframe
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['owner']   #used to get the owner column of the dataframe
# Out:
# 0       First Owner
# 1       First Owner
# 2       First Owner
# 3       First Owner
# 4       First Owner
#            ...
# 9362    First Owner
# 9369    First Owner
# 9370    First Owner
# 9371    First Owner
# 9372    First Owner
# Name: owner, Length: 7324, dtype: object

# %%
df['owner'].value_counts()   #used to get the count of unique values in the owner column
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
df['brand'].value_counts()  #used to get the count of unique values in the brand column
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['brand'].unique()   #used to get the unique values of the brand column
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].nunique()   #used to get the number of unique values in the brand column
# Out:
# 23

# %%
df.shape   #used to get the shape of the dataframe (number of rows, number of columns) also known as features
# Out:
# (7324, 8)

# %%
df.dtypes   #used to get the data types of the columns in the dataframe
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
royal_df=df[df['brand']=="Royal Enfield"] #used to filter the dataframe for rows where the brand is 'Royal Enfield'

# %%
royal_df
# Out:
#                                      bike_name     price       city  \
# 1                  Royal Enfield Classic 350cc  119900.0      Delhi
# 8            Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9     Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# 23          Royal Enfield Classic Chrome 500cc  121700.0     Kalyan
# 36                 Royal Enfield Classic 350cc   98800.0      Kochi
# ...                                        ...       ...        ...
# 9261               Royal Enfield Classic 500cc  146006.0   Guwahati
# 9319               Royal Enfield Classic 350cc  100000.0    Chennai
# 9337             Royal Enfield Himalayan 410cc  120000.0    Gurgaon
# 9338             Royal Enfield Himalayan 410cc  138000.0      Delhi
# 9344      Royal Enfield Bullet Twinspark 350cc   80000.0      Delhi
#
#       kms_driven         owner   age  power          brand
# 1        11000.0   First Owner   4.0  350.0  Royal Enfield
# ...

# %%
royal_2age_df= royal_df[royal_df["age"]<=2]   #used to filter the dataframe for rows where the brand is 'Royal Enfield'

# %%
royal_2age_df
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
royal_df[royal_df['kms_driven']<=10000]
# Out:
#                                      bike_name     price        city  \
# 8            Royal Enfield Thunderbird X 350cc  145000.0   Bangalore
# 38           Royal Enfield Thunderbird X 500cc  190500.0  Samastipur
# 42          Royal Enfield Bullet Electra 350cc   78000.0     Lucknow
# 70             Royal Enfield Thunderbird 350cc  110000.0       Delhi
# 72             Royal Enfield Thunderbird 350cc   65000.0   Jalandhar
# ...                                        ...       ...         ...
# 9235               Royal Enfield Classic 350cc  150000.0   Bangalore
# 9241  Royal Enfield Classic Desert Storm 500cc  140000.0       Delhi
# 9261               Royal Enfield Classic 500cc  146006.0    Guwahati
# 9337             Royal Enfield Himalayan 410cc  120000.0     Gurgaon
# 9338             Royal Enfield Himalayan 410cc  138000.0       Delhi
#
#       kms_driven        owner   age  power          brand
# 8         9190.0  First Owner   3.0  350.0  Royal Enfield
# ...

# %%
# brand=tvs
# age=1 se km
# price<=40000
# owner=1

# %%
tvs_df=df[df['brand']=="TVS"]   #used to filter the dataframe for rows where the brand is 'TVS'

# %%
tvs_df
# Out:
#                                bike_name    price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                   TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                  TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114           TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130               TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                  ...      ...        ...         ...
# 9247      TVS Apache RTR 160cc Rear Disc  70000.0  Ghaziabad      4116.0
# 9307                TVS Apache RTR 160cc  30000.0     Alibag     30000.0
# 9312            TVS Apache RTR 200 4V FI  65450.0      Delhi      9238.0
# 9320                    TVS Apache 150cc  20000.0     Hissar     84916.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner   age  power brand
# 0     First Owner   3.0  110.0   TVS
# ...

# %%
tvs_age_df=tvs_df[tvs_df["age"]==1]
tvs_age_df
# Out:
#                                        bike_name     price       city  \
# 1126  TVS Apache RTR 200 4V Dual Channel ABS BS6  130000.0  Bangalore
# 1132          TVS Apache RTR 160 4V DISC ABS BS6   98000.0     Jaipur
#
#       kms_driven        owner  age  power brand
# 1126      1300.0  First Owner  1.0  200.0   TVS
# 1132       749.0  First Owner  1.0  160.0   TVS

# %%
tvs_price_df=tvs_df[tvs_df['price']<=100000]
tvs_price_df
# Out:
#                                bike_name    price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                   TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                  TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114           TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130               TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                  ...      ...        ...         ...
# 9247      TVS Apache RTR 160cc Rear Disc  70000.0  Ghaziabad      4116.0
# 9307                TVS Apache RTR 160cc  30000.0     Alibag     30000.0
# 9312            TVS Apache RTR 200 4V FI  65450.0      Delhi      9238.0
# 9320                    TVS Apache 150cc  20000.0     Hissar     84916.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner   age  power brand
# 0     First Owner   3.0  110.0   TVS
# ...

# %%
royal_df=df[(df['brand']=="Royal Enfield") & 
            (df['kms_driven']<=30000) & 
            (df['owner']=='First Owner') & 
            (df['price']<=100000)]   #used to filter the dataframe for rows where the brand is 'Royal Enfield', kms driven is less than or equal to 30000, owner is 'First Owner' and price is less than or equal to 100000

# %%
royal_df
# Out:
#                                bike_name     price       city  kms_driven  \
# 42    Royal Enfield Bullet Electra 350cc   78000.0    Lucknow      8500.0
# 44           Royal Enfield Classic 350cc   85000.0      Delhi     18000.0
# 51           Royal Enfield‎ Bullet 350cc   90000.0      Delhi     15300.0
# 64       Royal Enfield Thunderbird 350cc   88000.0      Delhi     19000.0
# 72       Royal Enfield Thunderbird 350cc   65000.0  Jalandhar      9800.0
# ...                                  ...       ...        ...         ...
# 9181  Royal Enfield Bullet Electra 350cc   60350.0      Delhi     26381.0
# 9197         Royal Enfield Classic 350cc   90000.0     Jaipur     17000.0
# 9236     Royal Enfield Thunderbird 350cc   95000.0      Surat     22000.0
# 9252         Royal Enfield Classic 350cc  100000.0  Ghaziabad     15078.0
# 9319         Royal Enfield Classic 350cc  100000.0    Chennai     25000.0
#
#             owner   age  power          brand
# ...

# %%
df.query("brand=='Royal Enfield' and kms_driven==30000 and owner=='First Owner' and price<=100000")   #used to filter the dataframe for rows where the brand is 'Royal Enfield', price is less than or equal to 100000, owner is 'First Owner' and kms driven is 30000
# Out:
#                                bike_name     price     city  kms_driven  \
# 1311         Royal Enfield Classic 350cc   80000.0     Pune     30000.0
# 3783  Royal Enfield Bullet Electra 350cc   65000.0    Delhi     30000.0
# 5593     Royal Enfield Thunderbird 350cc   75000.0  Chennai     30000.0
# 6485     Royal Enfield Thunderbird 350cc   70000.0    Delhi     30000.0
# 6716         Royal Enfield Classic 350cc  100000.0  Chennai     30000.0
# 6719  Royal Enfield Bullet Electra 350cc   75000.0    Delhi     30000.0
# 7716         Royal Enfield Classic 350cc  100000.0    Delhi     30000.0
# 8012     Royal Enfield Thunderbird 350cc   75000.0     Pune     30000.0
#
#             owner   age  power          brand
# 1311  First Owner   5.0  350.0  Royal Enfield
# 3783  First Owner  11.0  350.0  Royal Enfield
# 5593  First Owner  10.0  350.0  Royal Enfield
# 6485  First Owner  11.0  350.0  Royal Enfield
# 6716  First Owner   5.0  350.0  Royal Enfield
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.rename(columns={'kms_driven':'kilometer'}, inplace=True)  #used to rename the column 'kms_driven' to 'kilometer'

# %%
df
# Out:
#                                  bike_name     price       city  kilometer  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad    17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi    11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi      110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore    16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore    10000.0
# ...                                    ...       ...        ...        ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi    48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore    60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur     3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad    21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad     7127.0
#
#             owner  age  power            brand
# ...

# %%
df.drop(columns=['bike_name','city'], axis=1,inplace=True)  #used to drop the column 'bike_name' and 'city' from the dataframe

# %%
df
# Out:
#          price  kilometer        owner  age  power            brand
# 0      35000.0    17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0    11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0      110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0    16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0    10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...        ...          ...  ...    ...              ...
# 9362   25000.0    48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0    60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0     3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0    21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0     7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df.to_csv('Cleaned_Used_Bikes.csv', index=False)  #used to save the dataframe to a csv file without the index

# %%
char=df.select_dtypes(include='object')  #used to get the columns with object data type or categorical data type

# %%
char
# Out:
#             owner            brand
# 0     First Owner              TVS
# 1     First Owner    Royal Enfield
# 2     First Owner          Triumph
# 3     First Owner              TVS
# 4     First Owner           Yamaha
# ...           ...              ...
# 9362  First Owner             Hero
# 9369  First Owner            Bajaj
# 9370  First Owner  Harley-Davidson
# 9371  First Owner            Bajaj
# 9372  First Owner            Bajaj
#
# [7324 rows x 2 columns]

# %%
num=df.select_dtypes(exclude='object') #used to get the columns with numeric data type

# %%
num
# Out:
#          price  kilometer  age  power
# 0      35000.0    17654.0  3.0  110.0
# 1     119900.0    11000.0  4.0  350.0
# 2     600000.0      110.0  8.0  675.0
# 3      65000.0    16329.0  4.0  180.0
# 4      80000.0    10000.0  3.0  150.0
# ...        ...        ...  ...    ...
# 9362   25000.0    48587.0  8.0  150.0
# 9369   35000.0    60000.0  9.0  220.0
# 9370  450000.0     3430.0  4.0  750.0
# 9371  139000.0    21300.0  4.0  400.0
# 9372   80000.0     7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
char['owner'].unique() #used to get the unique values of the owner column
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dict={
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4
}

# %%
char['owner'] = char['owner'].map(owner_dict)  #used to map the owner column with the owner_dict dictionary

# %%
char
# Out:
#       owner            brand
# 0       1.0              TVS
# 1       1.0    Royal Enfield
# 2       1.0          Triumph
# 3       1.0              TVS
# 4       1.0           Yamaha
# ...     ...              ...
# 9362    1.0             Hero
# 9369    1.0            Bajaj
# 9370    1.0  Harley-Davidson
# 9371    1.0            Bajaj
# 9372    1.0            Bajaj
#
# [7324 rows x 2 columns]

# %%
char['brand'].unique()  #used to get the unique values of the brand column
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()  #used to create an instance of the LabelEncoder class
char['brand'] = le.fit_transform(char['brand'])  #used to encode the brand column with numerical values

# %%
char
# Out:
#       owner  brand
# 0       1.0     19
# 1       1.0     17
# 2       1.0     20
# 3       1.0     19
# 4       1.0     21
# ...     ...    ...
# 9362    1.0      5
# 9369    1.0      1
# 9370    1.0      4
# 9371    1.0      1
# 9372    1.0      1
#
# [7324 rows x 2 columns]

# %%
char['brand'].unique()  #used to get the unique values of the brand column
# Out:
# array([19, 17, 20, 21,  6,  5,  1, 18,  2, 11, 15, 12,  3,  7,  4, 10,  0,
#         9, 16, 13, 22, 14,  8])

# %%
clean_data=pd.concat([char,num],axis=1)  #used to concatenate the numeric and categorical dataframes along the columns

# %%
clean_data
# Out:
#       owner  brand     price  kilometer  age  power
# 0       1.0     19   35000.0    17654.0  3.0  110.0
# 1       1.0     17  119900.0    11000.0  4.0  350.0
# 2       1.0     20  600000.0      110.0  8.0  675.0
# 3       1.0     19   65000.0    16329.0  4.0  180.0
# 4       1.0     21   80000.0    10000.0  3.0  150.0
# ...     ...    ...       ...        ...  ...    ...
# 9362    1.0      5   25000.0    48587.0  8.0  150.0
# 9369    1.0      1   35000.0    60000.0  9.0  220.0
# 9370    1.0      4  450000.0     3430.0  4.0  750.0
# 9371    1.0      1  139000.0    21300.0  4.0  400.0
# 9372    1.0      1   80000.0     7127.0  5.0  220.0
#
# [7324 rows x 6 columns]

# %%
clean_data.to_csv('new_Cleaned_Used_Bikes.csv', index=False)
