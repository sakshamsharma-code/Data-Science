# %%
import pandas as pd

# %%
idf=pd.read_csv('new_Cleaned_insurance.csv')

# %%
idf
# Out:
#       gender  smoker  age     bmi  children      charges
# 0          0       1   19  27.900         0  16884.92400
# 1          1       0   18  33.770         1   1725.55230
# 2          1       0   28  33.000         3   4449.46200
# 3          1       0   33  22.705         0  21984.47061
# 4          1       0   32  28.880         0   3866.85520
# ...      ...     ...  ...     ...       ...          ...
# 1332       1       0   50  30.970         3  10600.54830
# 1333       0       0   18  31.920         0   2205.98080
# 1334       0       0   18  36.850         0   1629.83350
# 1335       0       0   21  25.800         0   2007.94500
# 1336       0       1   61  29.070         0  29141.36030
#
# [1337 rows x 6 columns]

# %%
idf.dropna(inplace=True)
x = idf.drop('charges', axis=1)
y = idf[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.7292291093848737

# %%
lr.score(x_test, y_test) # Evaluate the model accuracy
# Out:
# 0.8046218811772661

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([[ 7780.09204548],
#        [ 5977.83338997],
#        [14215.82300956],
#        [31590.59473466],
#        [ 9223.64922442],
#        [13438.43822409],
#        [29841.65667782],
#        [ 1685.03795715],
#        [10919.46514725],
#        [11281.04050309],
#        [10418.78669104],
#        [33059.36084168],
#        [30531.50988264],
#        [17420.0023959 ],
#        [10214.90616935],
#        [ 9749.75223135],
#        [ 4298.47335596],
#        [32007.67725019],
#        [ 3488.96062241],
#        [ 5583.27330599],
#        [ 3845.53703027],
#        [29815.02239719],
#        [15103.39914515],
#        [30646.34708594],
#        [30908.30211535],
#        [ 5363.08477297],
#        [35705.172843  ],
#        [36714.56751572],
#        [10928.83748576],
#        [13689.22034633],
#        [ 5994.25520485],
#        [13015.10761713],
#        [  842.10884744],
#        [12332.40611586],
#        [39769.78804625],
#        [12472.16793437],
#        [ 4941.6340669 ],
# ...

# %%
y_test
# Out:
#           charges
# 899    8688.85885
# 1063   5708.86700
# 1255  11436.73815
# 298   38746.35510
# 237    4463.20510
# ...           ...
# 534   13831.11520
# 542   13887.20400
# 759    3925.75820
# 1283  47403.88000
# 1284   8534.67180
#
# [268 rows x 1 columns]

# %%
pred_idf = pd.DataFrame(pred, columns=["Predicted_Charges"]).reset_index(drop=True)
y_test_reset = y_test.reset_index(drop=True)
result = pd.concat([pred_idf, y_test_reset], axis=1)

# %%
result
# Out:
#      Predicted_Charges      charges
# 0          7780.092045   8688.85885
# 1          5977.833390   5708.86700
# 2         14215.823010  11436.73815
# 3         31590.594735  38746.35510
# 4          9223.649224   4463.20510
# ..                 ...          ...
# 263       17006.561344  13831.11520
# 264       15565.099818  13887.20400
# 265        5902.496661   3925.75820
# 266       38571.213833  47403.88000
# 267        7918.530325   8534.67180
#
# [268 rows x 2 columns]

# %%
import joblib
joblib.dump(lr, "ml_insurance.lb")
# Out:
# ['ml_insurance.lb']

# %%
joblib.load("ml_insurance.lb")
# Out:
# LinearRegression()
